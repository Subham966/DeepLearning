# %% [markdown]
# # Topics:
#
#   *Reading an image file and converting it to a numpy array
#
#   *Resizing an image
#
#   *RGB to Grayscale conversion

# %%
# getting an image using web get

# !wget ' https://www.google.com/imgres?imgurl=https%3A%2F%2Fhips.hearstapps.com%2Fhmg-prod%2Fimages%2Fgolden-retriever-royalty-free-image-506756303-1560962726.jpg%3Fcrop%3D1.00xw%3A0.756xh%3B0%2C0.0756xh%26resize%3D1200%3A*&tbnid=9Zv98XrDcfYCXM&vet=12ahUKEwibq5qhtYmAAxWajmMGHcAIDOsQMygNegUIARCDAg..i&imgrefurl=https%3A%2F%2Fwww.goodhousekeeping.com%2Flife%2Fpets%2Fadvice%2Fg1921%2Flarge-dog-breeds%2F&docid=FofFudZ0yWjNIM&w=1200&h=605&q=dog%20images&ved=2ahUKEwibq5qhtYmAAxWajmMGHcAIDOsQMygNegUIARCDAg'
# Out:
#  https://www.google.com/imgres?imgurl=https%3A%2F%2Fhips.hearstapps.com%2Fhmg-prod%2Fimages%2Fgolden-retriever-royalty-free-image-506756303-1560962726.jpg%3Fcrop%3D1.00xw%3A0.756xh%3B0%2C0.0756xh%26resize%3D1200%3A*&tbnid=9Zv98XrDcfYCXM&vet=12ahUKEwibq5qhtYmAAxWajmMGHcAIDOsQMygNegUIARCDAg..i&imgrefurl=https%3A%2F%2Fwww.goodhousekeeping.com%2Flife%2Fpets%2Fadvice%2Fg1921%2Flarge-dog-breeds%2F&docid=FofFudZ0yWjNIM&w=1200&h=605&q=dog%20images&ved=2ahUKEwibq5qhtYmAAxWajmMGHcAIDOsQMygNegUIARCDAg: Scheme missing.

# %% [markdown]
# # Libraries that can be used for image processing:
#
# 1.matplotlib.image
#
# 2.Pillow
#
# 3.OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/drive/MyDrive/DeepLearning/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (159, 316, 3)

# %%
print(img)
# Out:
# [[[ 89  81   0]
#   [ 96  86   0]
#   [ 95  81   6]
#   ...
#   [ 28  21  15]
#   [ 28  21  15]
#   [ 28  21  15]]
#
#  [[109 101   0]
#   [103  93   0]
#   [100  87   9]
#   ...
#   [ 28  21  15]
#   [ 28  21  15]
#   [ 28  21  15]]
#
#  [[130 122  11]
#   [111 101   3]
#   [106  93  15]
#   ...
#   [ 27  20  14]
#   [ 27  20  14]
#   [ 27  20  14]]
#
#  ...
#
#  [[224 223 140]
#   [136 136  48]
#   [103 104  11]
#   ...
#   [ 63  72  27]
#   [ 42  51   6]
#   [ 46  55  12]]
#
#  [[165 165  75]
#   [214 215 122]
#   [199 201 104]
#   ...
#   [ 63  73  21]
#   [ 42  52   2]
#   [ 46  56   6]]
#
#  [[166 169  62]
#   [126 130  19]
#   [190 195  79]
#   ...
#   [ 59  70  14]
#   [ 38  48   0]
#   [ 42  52   0]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/drive/MyDrive/DeepLearning/dog.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/drive/MyDrive/DeepLearning/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (159, 316, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (159, 316)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=316x159 at 0x7F3983577EB0>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
